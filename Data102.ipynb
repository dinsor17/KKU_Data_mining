# %% [markdown]
# <a href="https://colab.research.google.com/github/dinsor17/KKU_Data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os #นำเข้าไฟล์
import pandas as pd #แพนด้าจัดข้อมูลที่เป็นพวกตาราง
base_path = '/content/drive/My Drive/DWDM_material'
#สร้างตัวแปรเก็บโฟลเดอร์ที่เราต้องการ
data = pd.read_csv(os.path.join(base_path,'test.csv'))
data.head() #แสดงตาราง
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# #Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['y'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7febb997ef98>],
#  'caps': [<matplotlib.lines.Line2D at 0x7febb99929e8>,
#   <matplotlib.lines.Line2D at 0x7febb9992d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7febb99214a8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7febb9921128>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7febb99922e8>,
#   <matplotlib.lines.Line2D at 0x7febb9992668>]}

# %%
plt.boxplot(data['x'],vert=False) #จุดมุงหมายแรกคือการกระจายข้อมูล ต่อไปดูoutlier
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7febb9457128>],
#  'caps': [<matplotlib.lines.Line2D at 0x7febb9457b38>,
#   <matplotlib.lines.Line2D at 0x7febb9457eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7febb94625f8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7febb9462278>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7febb9457438>,
#   <matplotlib.lines.Line2D at 0x7febb94577b8>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2) #ต้องการกำหนดwhisเกอร์ให้มัน เพราะไม่อยากได้ 1.5iqrแล้ว
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7febb98d9cc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7febb9473208>,
#   <matplotlib.lines.Line2D at 0x7febb9917a58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7febb94880b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7febb9488358>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7febb98d9f60>,
#   <matplotlib.lines.Line2D at 0x7febb947bfd0>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['fliers'][0] #คือสัญลักษ์ของลิส

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=25) #s คือไซส์ของจุด

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='r') #cคือcolorสี r=red

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='c',marker='>',alpha=0.4) #alphaคือความโปร่งแสง
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6)

# %% [markdown]
# ##HW4 วาดปีกกับนอ ให้ไดโนเสาร์ ส่งจัน

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='k',marker='<') #ตัว
plt.scatter([50],[80],s=50,c='r')
plt.scatter([50],[80],s=200,alpha=0.3,c='r')  
plt.scatter([34,32,30,28,26,24,22,24,26,28,30,32,34,36,38,40,42,84,86,88,90,92,94,96,98,100,100,100,98,96,94,92,90,88,86,84,82,82,82,82,82,82],[83,85,87,89,91,93,95,94,94,94,94,94,94,94,94,94,94,35,38,41,44,47,50,53,56,59,63,68,72,75,74,71,68,65,61,58,54,50,46,42,38,35],s=100,alpha=0.6,c='c')
